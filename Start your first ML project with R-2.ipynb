# %%
#数据可视化操作

# %%
#单变量图像

# %%
x<-train[,1:4]

# %%
y<-train[,5]

# %%
par(mfrow=c(1,4))
for(i in 1:4){
    boxplot(x[,i],main=names(iris)[i])
    }#箱线图
# Out:
# Plot with title “Petal.Width”

# %%
plot(y)
# Out:
# plot without title
